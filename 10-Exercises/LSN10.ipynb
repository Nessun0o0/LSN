# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
optimal = np.loadtxt("output.out", dtype=int) - 1
optimal = np.append(optimal, optimal[0])
single_core = np.loadtxt("OUTPUT/single_core.out", dtype=int) - 1
single_core = np.append(single_core, single_core[0])
cities = np.loadtxt("cap_prov_ita.dat")

fig, ax = plt.subplots(1, 2, figsize=(15,7))

ax[0].plot(cities[optimal,0], cities[optimal,1])
ax[1].plot(cities[single_core,0], cities[single_core,1])

# %% [markdown]
# Per ora il migliore con 10000000 2 0.01

# %%
Tmin = 1e-3
Tmax = 2.
r = np.power(Tmax/Tmin, 1/15)

[Tmin*np.power(r,i) for i in range(16)]
# Out:
# [0.001,
#  0.0016598493257629445,
#  0.0027550997842357016,
#  0.004573050519273263,
#  0.00759057482109561,
#  0.01259921049894873,
#  0.02091279105182546,
#  0.03471208212719383,
#  0.057616826114650646,
#  0.09563524997900368,
#  0.15874010519681991,
#  0.2634846565824804,
#  0.4373448295773111,
#  0.7259265204998098,
#  1.2049286456050494,
#  1.9999999999999993]

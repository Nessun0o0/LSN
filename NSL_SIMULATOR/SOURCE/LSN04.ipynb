# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
v, pofv, err = np.loadtxt("../OUTPUT/pofv.dat", unpack=True)
print(pofv)
plt.errorbar(v, pofv, err, fmt=".");
# Out:
# [0.00213056 0.013859   0.0327882  0.0593801  0.0876539  0.107869
#  0.124007   0.115756   0.114851   0.09445    0.0816382  0.05931
#  0.0397109  0.0285343  0.0172683  0.00991551 0.00451667 0.00260741
#  0.00134745 0.00139514 0.0006081  0.00019815 0.00020486 0.
#  0.         0.         0.         0.         0.         0.        ]
# <ErrorbarContainer object of 3 artists>

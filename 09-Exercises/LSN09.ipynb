# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
optimal = np.loadtxt("square.out", dtype=int, max_rows=1) - 1
cities = np.loadtxt("square.out", skiprows=1)

plt.plot(cities[optimal,0], cities[optimal,1])

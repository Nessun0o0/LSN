# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory </span>
# ## <span style="color:brown"> Python Exercise 11 </span>
# ## <span style="color:orange"> Keras - Neural Network regression </span>

# %% [markdown]
# ### Overview
#
# In this notebook our task will be to perform machine learning regression on noisy data with a Neural Network (NN).
#
# We will explore how the ability to fit depends on the structure of the NN. The goal is also to build intuition about why prediction is difficult.

# %% [markdown]
# ### The Prediction Problem
#
# Consider a probabilistic process that gives rise to labeled data $(x,y)$. The data is generated by drawing samples from the equation
#
# $$
#     y_i= f(x_i) + \eta_i,
# $$
#
# where $f(x_i)$ is some fixed, but (possibly unknown) function, and $\eta_i$ is a Gaussian, uncorrelate noise variable such that
#
# $$
# \langle \eta_i \rangle=0 \\
# \langle \eta_i \eta_j \rangle = \delta_{ij} \sigma
# $$
#
# We will refer to the $f(x_i)$ as the **true features** used to generate the data.
#
# To make predictions, we will consider a NN that depends on its parameters, weights and biases. The functions that the NN can model respresent the **model class** that we are using to try to model the data and make predictions.
#
# To learn the parameters of the NN, we will train our models on a **training data set** and then test the effectiveness of the NN on a *different* dataset, the **validation data set**. The reason we must divide our data into a training and test dataset is that the point of machine learning is to make accurate predictions about new data we have not seen.
#
# To measure our ability to predict, we will learn our parameters by fitting our training dataset and then making predictions on our test data set. One common measure of predictive  performance of our algorithm is to compare the predictions,$\{y_j^\mathrm{pred}\}$, to the true values $\{y_j\}$. A commonly employed measure for this is the sum of the mean square-error (MSE) on the test set:
# $$
# MSE= \frac{1}{N_\mathrm{test}}\sum_{j=1}^{N_\mathrm{test}} (y_j^\mathrm{pred}-y_j)^2
# $$
#
# We will try to get a qualitative picture by examining plots on validation and training data.

# %% [markdown]
# ### Linear fit
#
# We start by considering the very simple case:
# $$
# f(x)=2x+1
# $$

# %% [markdown]
# Let's start defining the parameters of an ideal linear function which we are going to predict through a neural network regression

# %%
# target parameters of f(x) = m*x + b
m = 2 # slope
b = 1 # intersect

# %% [markdown]
# Now let's generate a set of input data which will slightly deviate from our ideal behaviour using a random noise (that actually is set to zero):

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 5000)
x_valid = np.random.uniform(-1, 1, 50)
x_valid.sort()
y_target = m * x_valid + b # ideal (target) linear function

sigma = 0.1 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)

# %%
# plot validation and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target, label='target')
plt.scatter(x_valid, y_valid, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# If you remember how a single node of a neural network works, you can easily spot that **just a single neuron can make the job**. So let's start using a simple Sequential model with just one layer on one neuron only!

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
#model.add(Input(shape=(1,)))
#model.add(Dense(1))

model = tf.keras.Sequential()
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
# get a summary of our composed model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We are now going to train our model, that is we feed the neuron with the set of training pair x, y_train from which the optimizer will find the best weights to minimize the Mean Square Error loss function (out linear regression function).

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=50,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/50
# 157/157 [==============================] - 0s 1ms/step - loss: 1.5565 - mse: 1.5565 - val_loss: 0.3307 - val_mse: 0.3307
# Epoch 2/50
# 157/157 [==============================] - 0s 626us/step - loss: 0.1802 - mse: 0.1802 - val_loss: 0.0479 - val_mse: 0.0479
# Epoch 3/50
# 157/157 [==============================] - 0s 636us/step - loss: 0.0305 - mse: 0.0305 - val_loss: 0.0149 - val_mse: 0.0149
# Epoch 4/50
# 157/157 [==============================] - 0s 637us/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 5/50
# 157/157 [==============================] - 0s 620us/step - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 6/50
# 157/157 [==============================] - 0s 652us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 7/50
# 157/157 [==============================] - 0s 655us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 8/50
# 157/157 [==============================] - 0s 663us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 9/50
# 157/157 [==============================] - 0s 668us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 10/50
# 157/157 [==============================] - 0s 620us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 11/50
# 157/157 [==============================] - 0s 638us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 12/50
# 157/157 [==============================] - 0s 619us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 13/50
# 157/157 [==============================] - 0s 615us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 14/50
# 157/157 [==============================] - 0s 630us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 15/50
# 157/157 [==============================] - 0s 660us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 16/50
# 157/157 [==============================] - 0s 624us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 17/50
# 157/157 [==============================] - 0s 622us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 18/50
# 157/157 [==============================] - 0s 623us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 19/50
# 157/157 [==============================] - 0s 636us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 20/50
# 157/157 [==============================] - 0s 625us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 21/50
# 157/157 [==============================] - 0s 632us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 22/50
# 157/157 [==============================] - 0s 622us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 23/50
# 157/157 [==============================] - 0s 657us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 24/50
# 157/157 [==============================] - 0s 661us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 25/50
# 157/157 [==============================] - 0s 642us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 26/50
# 157/157 [==============================] - 0s 622us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 27/50
# 157/157 [==============================] - 0s 620us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 28/50
# 157/157 [==============================] - 0s 634us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 29/50
# 157/157 [==============================] - 0s 626us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 30/50
# 157/157 [==============================] - 0s 644us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 31/50
# 157/157 [==============================] - 0s 646us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 32/50
# 157/157 [==============================] - 0s 638us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 33/50
# 157/157 [==============================] - 0s 637us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 34/50
# 157/157 [==============================] - 0s 623us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 35/50
# 157/157 [==============================] - 0s 619us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 36/50
# 157/157 [==============================] - 0s 631us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 37/50
# 157/157 [==============================] - 0s 645us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 38/50
# 157/157 [==============================] - 0s 627us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 39/50
# 157/157 [==============================] - 0s 630us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 40/50
# 157/157 [==============================] - 0s 623us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 41/50
# 157/157 [==============================] - 0s 641us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 42/50
# 157/157 [==============================] - 0s 622us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 43/50
# 157/157 [==============================] - 0s 605us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 44/50
# 157/157 [==============================] - 0s 603us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 45/50
# 157/157 [==============================] - 0s 643us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 46/50
# 157/157 [==============================] - 0s 621us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 47/50
# 157/157 [==============================] - 0s 616us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 48/50
# 157/157 [==============================] - 0s 614us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 49/50
# 157/157 [==============================] - 0s 622us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 50/50
# 157/157 [==============================] - 0s 601us/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0116 - val_mse: 0.0116

# %% [markdown]
# By looking at weights and biases we can see if the linear fit was successfull: $w_1$ represents the angular coefficient, $b$ the intercept.

# %%
# return weights and biases
model.get_weights()
# Out:
# [array([[1.9993069]], dtype=float32), array([0.99689645], dtype=float32)]

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0116 - mse: 0.0116
#
# Test loss: 0.01161160971969366
# Test accuracy: 0.01161160971969366

# %%
# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 3.9213e-07 - mse: 3.9213e-07
#
# Test loss: 3.921319091659825e-07
# Test accuracy: 3.921319091659825e-07

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()
# Out:
# 4/4 [==============================] - 0s 763us/step

# %% [markdown]
# ### Exercise 11.1
#
# In order to make practice with NN, explore how does the previous linear regression depend on the number of epochs, $N_{\mathrm{epochs}}$, the number of data points $N_{\mathrm{train}}$ and on the noise $\sigma$. Try to improve the previous result operating on these parameters.

# %% [markdown]
# ### Exercise 11.2
#
# Try to extend the model to obtain a reasonable fit of the following polynomial of order 3:
#
# $$
# f(x)=4-3x-2x^2+3x^3
# $$
# for $x \in [-1,1]$.
#
# Find good (& reasonable) choices for:
#
# - the number of layers
# - the number of neurons in each layer
# - the activation function
# - the optimizer
# - the loss function
#
# Check your NN model by seeing how well your fits predict newly generated test data (including on data outside the range you fit. How well do your NN do on points in the range of $x$ where you trained the model? How about points outside the original training data set?
# Summarize what you have learned about the relationship between model complexity (number of parameters), goodness of fit on training data, and the ability to predict well.

# %%
def f(x):
    return 4 -3 * x - 2 * np.power(x, 2) + 3 * np.power(x, 3)

# %%
# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 500)
x_valid = np.random.uniform(-1, 1, 50)
x_valid.sort()
y_target = f(x_valid) # ideal (target) linear function

sigma = 0.2 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(f(x_train), sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(f(x_valid), sigma)

# %%
model = tf.keras.Sequential()

model = tf.keras.Sequential()
model.add(Dense(8, input_shape=(1,),activation="tanh"))
model.add(Dense(8, activation="relu"))
model.add(Dense(1))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
# plot validation and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target, label='target')
plt.scatter(x_valid, y_valid, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %%
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=40,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/40
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0427 - mse: 0.0427 - val_loss: 0.0422 - val_mse: 0.0422
# Epoch 2/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0426 - mse: 0.0426 - val_loss: 0.0417 - val_mse: 0.0417
# Epoch 3/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0426 - mse: 0.0426 - val_loss: 0.0418 - val_mse: 0.0418
# Epoch 4/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0423 - mse: 0.0423 - val_loss: 0.0426 - val_mse: 0.0426
# Epoch 5/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0425 - mse: 0.0425 - val_loss: 0.0446 - val_mse: 0.0446
# Epoch 6/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0424 - mse: 0.0424 - val_loss: 0.0412 - val_mse: 0.0412
# Epoch 7/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0423 - mse: 0.0423 - val_loss: 0.0415 - val_mse: 0.0415
# Epoch 8/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0422 - mse: 0.0422 - val_loss: 0.0444 - val_mse: 0.0444
# Epoch 9/40
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0422 - mse: 0.0422 - val_loss: 0.0429 - val_mse: 0.0429
# Epoch 10/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0421 - mse: 0.0421 - val_loss: 0.0428 - val_mse: 0.0428
# Epoch 11/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0420 - mse: 0.0420 - val_loss: 0.0410 - val_mse: 0.0410
# Epoch 12/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0419 - mse: 0.0419 - val_loss: 0.0412 - val_mse: 0.0412
# Epoch 13/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0420 - mse: 0.0420 - val_loss: 0.0430 - val_mse: 0.0430
# Epoch 14/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0419 - mse: 0.0419 - val_loss: 0.0407 - val_mse: 0.0407
# Epoch 15/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0419 - mse: 0.0419 - val_loss: 0.0407 - val_mse: 0.0407
# Epoch 16/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0417 - mse: 0.0417 - val_loss: 0.0406 - val_mse: 0.0406
# Epoch 17/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0417 - mse: 0.0417 - val_loss: 0.0413 - val_mse: 0.0413
# Epoch 18/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0417 - mse: 0.0417 - val_loss: 0.0408 - val_mse: 0.0408
# Epoch 19/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0417 - mse: 0.0417 - val_loss: 0.0409 - val_mse: 0.0409
# Epoch 20/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0417 - mse: 0.0417 - val_loss: 0.0416 - val_mse: 0.0416
# Epoch 21/40
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0416 - mse: 0.0416 - val_loss: 0.0419 - val_mse: 0.0419
# Epoch 22/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0415 - mse: 0.0415 - val_loss: 0.0404 - val_mse: 0.0404
# Epoch 23/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0414 - mse: 0.0414 - val_loss: 0.0409 - val_mse: 0.0409
# Epoch 24/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0415 - mse: 0.0415 - val_loss: 0.0403 - val_mse: 0.0403
# Epoch 25/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0415 - mse: 0.0415 - val_loss: 0.0409 - val_mse: 0.0409
# Epoch 26/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0415 - mse: 0.0415 - val_loss: 0.0402 - val_mse: 0.0402
# Epoch 27/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0413 - mse: 0.0413 - val_loss: 0.0408 - val_mse: 0.0408
# Epoch 28/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0414 - mse: 0.0414 - val_loss: 0.0403 - val_mse: 0.0403
# Epoch 29/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0412 - mse: 0.0412 - val_loss: 0.0405 - val_mse: 0.0405
# Epoch 30/40
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0414 - mse: 0.0414 - val_loss: 0.0402 - val_mse: 0.0402
# Epoch 31/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0413 - mse: 0.0413 - val_loss: 0.0412 - val_mse: 0.0412
# Epoch 32/40
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0412 - mse: 0.0412 - val_loss: 0.0403 - val_mse: 0.0403
# Epoch 33/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0414 - mse: 0.0414 - val_loss: 0.0401 - val_mse: 0.0401
# Epoch 34/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0413 - mse: 0.0413 - val_loss: 0.0405 - val_mse: 0.0405
# Epoch 35/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0413 - mse: 0.0413 - val_loss: 0.0403 - val_mse: 0.0403
# Epoch 36/40
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0414 - mse: 0.0414 - val_loss: 0.0404 - val_mse: 0.0404
# Epoch 37/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0412 - mse: 0.0412 - val_loss: 0.0428 - val_mse: 0.0428
# Epoch 38/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0412 - mse: 0.0412 - val_loss: 0.0404 - val_mse: 0.0404
# Epoch 39/40
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0412 - mse: 0.0412 - val_loss: 0.0400 - val_mse: 0.0400
# Epoch 40/40
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0411 - mse: 0.0411 - val_loss: 0.0428 - val_mse: 0.0428

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()
# Out:
# 4/4 [==============================] - 0s 7ms/step

# %% [markdown]
# ### Exercise 11.3
#
# Try to extend the model to fit a simple trigonometric 2D function such as $f(x,y) = \sin(x^2+y^2)$ in the range $x \in [-3/2,3/2]$ and $y \in [-3/2,3/2]$.

# %%
def f(x, y):
    return np.sin(np.power(x, 2) + np.power(y, 2))

# %%
# generate training inputs
np.random.seed(0)
n_train = 500
n_valid = 50
x_train = np.reshape(np.random.uniform(-1.5, 1.5, 2*n_train), (n_train,2))
x_valid = np.reshape(np.random.uniform(-1.5, 1.5, 2*n_valid), (n_valid,2))

y_target = f(x_valid[:,0], x_valid[:,1]) # ideal (target) linear function

sigma = 0.2 # noise standard deviation, for the moment it is absent
f_train = np.random.normal(f(x_train[:,0], x_train[:,1]), sigma) # actual measures from which we want to guess regression parameters
f_valid = np.random.normal(f(x_valid[:,0], x_valid[:,1]), sigma)

# %%
model = tf.keras.Sequential()

model = tf.keras.Sequential()
model.add(Dense(8, input_shape=(2,),activation="tanh"))
model.add(Dense(8, activation="relu"))
model.add(Dense(1))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=40,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/40
# 16/16 [==============================] - 0s 16ms/step - loss: 0.4146 - mse: 0.4146 - val_loss: 0.4786 - val_mse: 0.4786
# Epoch 2/40
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3840 - mse: 0.3840 - val_loss: 0.4678 - val_mse: 0.4678
# Epoch 3/40
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3711 - mse: 0.3711 - val_loss: 0.4631 - val_mse: 0.4631
# Epoch 4/40
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3635 - mse: 0.3635 - val_loss: 0.4603 - val_mse: 0.4603
# Epoch 5/40
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3581 - mse: 0.3581 - val_loss: 0.4584 - val_mse: 0.4584
# Epoch 6/40
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3538 - mse: 0.3538 - val_loss: 0.4565 - val_mse: 0.4565
# Epoch 7/40
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3501 - mse: 0.3501 - val_loss: 0.4547 - val_mse: 0.4547
# Epoch 8/40
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3468 - mse: 0.3468 - val_loss: 0.4535 - val_mse: 0.4535
# Epoch 9/40
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3442 - mse: 0.3442 - val_loss: 0.4512 - val_mse: 0.4512
# Epoch 10/40
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3422 - mse: 0.3422 - val_loss: 0.4501 - val_mse: 0.4501
# Epoch 11/40
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3411 - mse: 0.3411 - val_loss: 0.4481 - val_mse: 0.4481
# Epoch 12/40
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3397 - mse: 0.3397 - val_loss: 0.4456 - val_mse: 0.4456
# Epoch 13/40
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3391 - mse: 0.3391 - val_loss: 0.4432 - val_mse: 0.4432
# Epoch 14/40
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3390 - mse: 0.3390 - val_loss: 0.4428 - val_mse: 0.4428
# Epoch 15/40
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3386 - mse: 0.3386 - val_loss: 0.4410 - val_mse: 0.4410
# Epoch 16/40
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3378 - mse: 0.3378 - val_loss: 0.4406 - val_mse: 0.4406
# Epoch 17/40
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3375 - mse: 0.3375 - val_loss: 0.4404 - val_mse: 0.4404
# Epoch 18/40
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3374 - mse: 0.3374 - val_loss: 0.4395 - val_mse: 0.4395
# Epoch 19/40
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3372 - mse: 0.3372 - val_loss: 0.4382 - val_mse: 0.4382
# Epoch 20/40
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3368 - mse: 0.3368 - val_loss: 0.4370 - val_mse: 0.4370
# Epoch 21/40
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3366 - mse: 0.3366 - val_loss: 0.4364 - val_mse: 0.4364
# Epoch 22/40
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3365 - mse: 0.3365 - val_loss: 0.4349 - val_mse: 0.4349
# Epoch 23/40
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3361 - mse: 0.3361 - val_loss: 0.4347 - val_mse: 0.4347
# Epoch 24/40
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3360 - mse: 0.3360 - val_loss: 0.4335 - val_mse: 0.4335
# Epoch 25/40
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3357 - mse: 0.3357 - val_loss: 0.4333 - val_mse: 0.4333
# Epoch 26/40
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3357 - mse: 0.3357 - val_loss: 0.4340 - val_mse: 0.4340
# Epoch 27/40
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3356 - mse: 0.3356 - val_loss: 0.4345 - val_mse: 0.4345
# Epoch 28/40
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3356 - mse: 0.3356 - val_loss: 0.4321 - val_mse: 0.4321
# Epoch 29/40
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3353 - mse: 0.3353 - val_loss: 0.4314 - val_mse: 0.4314
# Epoch 30/40
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3352 - mse: 0.3352 - val_loss: 0.4309 - val_mse: 0.4309
# Epoch 31/40
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3353 - mse: 0.3353 - val_loss: 0.4307 - val_mse: 0.4307
# Epoch 32/40
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3349 - mse: 0.3349 - val_loss: 0.4295 - val_mse: 0.4295
# Epoch 33/40
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3353 - mse: 0.3353 - val_loss: 0.4285 - val_mse: 0.4285
# Epoch 34/40
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3350 - mse: 0.3350 - val_loss: 0.4292 - val_mse: 0.4292
# Epoch 35/40
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3349 - mse: 0.3349 - val_loss: 0.4284 - val_mse: 0.4284
# Epoch 36/40
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3349 - mse: 0.3349 - val_loss: 0.4284 - val_mse: 0.4284
# Epoch 37/40
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3345 - mse: 0.3345 - val_loss: 0.4287 - val_mse: 0.4287
# Epoch 38/40
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3347 - mse: 0.3347 - val_loss: 0.4277 - val_mse: 0.4277
# Epoch 39/40
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3347 - mse: 0.3347 - val_loss: 0.4279 - val_mse: 0.4279
# Epoch 40/40
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3347 - mse: 0.3347 - val_loss: 0.4273 - val_mse: 0.4273

# %%
x_predicted = np.reshape(np.random.uniform(-1.5, 1.5, 2*100), (100,2))
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()
# Out:
# 4/4 [==============================] - 0s 2ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_428771/3311374714.py in <module>
#       1 x_predicted = np.reshape(np.random.uniform(-1.5, 1.5, 2*100), (100,2))
#       2 y_predicted = model.predict(x_predicted)
# ----> 3 plt.scatter(x_predicted, y_predicted,color='r')
#       4 plt.plot(x_valid, y_target)
#       5 plt.grid(True)
#
# /tools/python/anaconda3/envs/DeepLearning/lib/python3.9/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2805         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2806         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2807     __ret = gca().scatter(
#    2808         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2809         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# /tools/python/anaconda3/envs/DeepLearning/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# /tools/python/anaconda3/envs/DeepLearning/lib/python3.9/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4321         y = np.ma.ravel(y)
#    4322         if x.size != y.size:
# -> 4323             raise ValueError("x and y must be the same size")
#    4324
#    4325         if s is None:
#
# ValueError: x and y must be the same size

# %% [markdown]
# Ideas to meditate on these exercises and judge your results can be found <a href=https://xkcd.com/2048/>here</a>
